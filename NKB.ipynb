# 32   4.05  2650  0.60  0.50  0.89   6  1.10  0.55  0.03  0.19  0.046
# 7    2.86  2650  0.50  0.60  1.05   6  0.72  0.43  0.04  0.25  0.086
# 34  11.25  2650  1.00  0.70  0.53   6  1.33  0.93  0.04  0.25  0.022
# 2    1.08  2650  0.60  0.60  0.56   1  0.89  0.54  0.04  0.04  0.037
# 26   2.43  2650  0.70  0.75  1.15   4  0.80  0.60  0.06  0.25  0.102
# 42   6.93  2660  0.70  0.75  0.71   7  0.80  0.60  0.06  0.44  0.063
# 10   8.80  2610  0.75  0.60  1.02  12  0.67  0.40  0.09  1.12  0.127
# 36   5.18  2510  0.80  0.70  0.46   3  0.71  0.50  0.07  0.20  0.039
# 28   8.06  2625  0.70  0.50  1.39  16  1.20  0.60  0.06  1.00  0.124
# 21   5.02  2650  0.75  0.60  1.19   8  1.17  0.70  0.03  0.25  0.049
# 33   6.93  2650  0.75  0.60  0.65   6  1.17  0.70  0.03  0.19  0.027
# 14   6.53  2600  0.80  0.60  0.98   8  1.17  0.70  0.06  0.50  0.077
# ...

# %%
y_train
# Out:
# 42     5.0
# 45     1.0
# 17     5.0
# 43    16.0
# 22     1.5
# 11     3.0
# 32     3.0
# 7      5.5
# 13     5.5
# 37     7.0
# 8      2.2
# 41     1.2
# 26    10.0
# 44     7.5
# 15    10.0
# 1      0.5
# 27     2.0
# 29     8.0
# 14    11.0
# 10    15.2
# 12    18.0
# 9      6.8
# 4      2.5
# 48     3.0
# 39     4.8
# 28    17.0
# 16     2.0
# 31     5.0
# 5      0.5
# 33     2.0
# 25     0.5
# 35     0.5
# 20     5.0
# 40     2.0
# Name: L, dtype: float64

# %%
y_test
# Out:
# 4      2.5
# 32     3.0
# 7      5.5
# 34     1.0
# 2      3.0
# 26    10.0
# 42     5.0
# 10    15.2
# 36     4.0
# 28    17.0
# 21     2.0
# 33     2.0
# 14    11.0
# 31     5.0
# 35     0.5
# Name: L, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()
clf.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#         A     B     C     D     E   F     G     H     I     J      K
# 4    1.32  2650  0.60  0.55  0.45   1  0.97  0.54  0.04  0.04  0.030
# 32   4.05  2650  0.60  0.50  0.89   6  1.10  0.55  0.03  0.19  0.046
# 7    2.86  2650  0.50  0.60  1.05   6  0.72  0.43  0.04  0.25  0.086
# 34  11.25  2650  1.00  0.70  0.53   6  1.33  0.93  0.04  0.25  0.022
# 2    1.08  2650  0.60  0.60  0.56   1  0.89  0.54  0.04  0.04  0.037
# 26   2.43  2650  0.70  0.75  1.15   4  0.80  0.60  0.06  0.25  0.102
# 42   6.93  2660  0.70  0.75  0.71   7  0.80  0.60  0.06  0.44  0.063
# 10   8.80  2610  0.75  0.60  1.02  12  0.67  0.40  0.09  1.12  0.127
# 36   5.18  2510  0.80  0.70  0.46   3  0.71  0.50  0.07  0.20  0.039
# 28   8.06  2625  0.70  0.50  1.39  16  1.20  0.60  0.06  1.00  0.124
# 21   5.02  2650  0.75  0.60  1.19   8  1.17  0.70  0.03  0.25  0.049
# 33   6.93  2650  0.75  0.60  0.65   6  1.17  0.70  0.03  0.19  0.027
# 14   6.53  2600  0.80  0.60  0.98   8  1.17  0.70  0.06  0.50  0.077
# ...

# %%
#clf.predict()

# %%
clf.score(X_test, y_test)
# Out:
# 0.6974537541077364

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=10)
X_test
# Out:
#        A     B     C     D     E   F     G     H     I     J      K
# 37  0.79  2490  0.40  0.50  0.51   1  0.66  0.33  0.04  0.04  0.053
# 23  7.26  2650  0.60  0.80  0.83  10  0.69  0.55  0.03  0.31  0.043
# 43  5.63  2600  0.70  0.60  0.75   6  1.00  0.60  0.09  0.56  0.099
# 41  1.44  2650  0.50  0.60  0.35   1  0.72  0.43  0.04  0.04  0.028
# 46  7.50  2625  0.90  0.60  1.20  10  0.83  0.50  0.13  1.25  0.167
# 20  8.42  2650  0.75  0.60  0.89  10  1.17  0.70  0.03  0.31  0.037
# 3   1.16  2650  0.40  0.55  0.35   1  0.61  0.34  0.04  0.04  0.035
# 30  5.32  2625  0.75  0.70  1.13   8  0.98  0.68  0.04  0.33  0.062
# 7   2.86  2650  0.50  0.60  1.05   6  0.72  0.43  0.04  0.25  0.086
# 6   2.38  2650  0.70  0.60  0.59   2  1.08  0.65  0.03  0.06  0.026
# 38  2.07  2560  0.70  0.60  0.68   2  0.92  0.55  0.07  0.10  0.048
# 2   1.08  2650  0.60  0.60  0.56   1  0.89  0.54  0.04  0.04  0.037
# 39  1.32  2650  0.60  0.55  0.45   1  0.97  0.54  0.04  0.04  0.030
# ...

# %%
#Save Model To a File Using Python Pickle
import pickle

# %%
with open('model_fd','wb') as file:
    pickle.dump(clf,file)

# %%
#Load Saved Model
with open('model_fd','rb') as file:
    mp = pickle.load(file)

# %%
#predict
#mp.predict([1.1, 2650, 0.40, 0.55, 0.35, 1	0.61, 0.34, 0.04, 0.04, 0.035])

# %%
#samplesuse_samples = [1.1, 2650, 0.40, 0.55, 0.35, 1, 0.61, 0.34, 0.04, 0.04, 0.035]
#arraysamples_to_predict = np.array(samplesuse_samples)

# %%
mp.predict([[1.1, 2650, 0.40, 0.55, 0.35, 1, 0.61, 0.34, 0.04, 0.04, 0.035]])
# Out:
# array([3.24734777])
